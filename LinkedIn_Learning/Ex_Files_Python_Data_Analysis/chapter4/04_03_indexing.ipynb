# %% [markdown]
# # 04_03: Indexing and Slicing NumPy Arrays

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
monalisa = np.load('monalisa.npy')

# %%
monalisa.shape
# Out:
# (1198, 804, 3)

# %%
pp.imshow(monalisa)

# %%
monalisa[600,400,0]
# Out:
# 247

# %%
monalisa[-50,-50,1]
# Out:
# 11

# %%
monalisa[1148, 754, 1]
# Out:
# 11

# %%
monalisa[1000,90,2]
# Out:
# 33

# %%
monalisa[600,400,0] = monalisa[600,400,1] = monalisa[600,400,2] = 0

# %%
just_a_list = [[1,2,3],[4,5,6],[7,8,9]]

# %%
just_a_list[1][2]
# Out:
# 6

# %%
pp.imshow(monalisa[400:800,200:300,0:3])

# %%
pp.imshow(monalisa[400:800,:,:])

# %%
pp.imshow(monalisa[400:800,...])

# %%
pp.imshow(monalisa[::20,::20,:])

# %%
pp.imshow(monalisa[::-20,::20,:])

# %%
row = monalisa[20,::20,0]

# %%
row.shape
# Out:
# (41,)

# %%
row
# Out:
# array([104,  81, 107, 100,  90,  98,  94, 103, 103,  97,  99, 105, 116,
#        100,  90,  97,  85,  97,  93,  97, 104,  94,  85, 112,  92,  98,
#         88,  81, 106,  79,  80,  91,  82, 100, 104,  88,  88,  79,  81,
#         81,  88], dtype=uint8)

# %%
pp.plot(monalisa[20,::20,0])

# %%
rect = monalisa[20:21,::20,0]

# %%
rect.shape
# Out:
# (1, 41)

# %%
rect
# Out:
# array([[104,  81, 107, 100,  90,  98,  94, 103, 103,  97,  99, 105, 116,
#         100,  90,  97,  85,  97,  93,  97, 104,  94,  85, 112,  92,  98,
#          88,  81, 106,  79,  80,  91,  82, 100, 104,  88,  88,  79,  81,
#          81,  88]], dtype=uint8)

# %%
monalisa[20:300,20:300,:] = 255

# %%
pp.imshow(monalisa)

# %%
monalisa[20:300,20:300,:] = np.random.randint(0,255,size=(280,280,3))

# %%
pp.matshow(monalisa)

# %%
monalisa_bw = np.loadtxt('monalisa.txt')

# %%
monalisa_bw < 120
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
monalisa_bw[monalisa_bw < 60] = 255

# %%
pp.imshow(monalisa_bw, cmap='gray')

# %%
mylist = [0,1,2,3,4,5]

# %%
myslice = mylist[0:4]

# %%
myslice[2] = myslice[3] = 100

# %%
myslice
# Out:
# [0, 1, 100, 100]

# %%
mylist
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
monaslice = monalisa[20:300,20:300,:]

# %%
monaslice[:,:,:] = 255

# %%
pp.imshow(monalisa)

# %%
monacopy = monalisa.copy()

# %%
monacopy[400:750,400:750,:] = 0

# %%
pp.imshow(monacopy)

# %%
pp.imshow(monalisa)
